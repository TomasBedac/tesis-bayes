# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import beta, norm
import stan
import nest_asyncio
from mpl_toolkits.mplot3d import Axes3D
nest_asyncio.apply()
import time
import arviz as az
import itertools

# %%
# Distribution parameters
alpha_b = 6  # Beta distribution for 'b'
beta_param_b = 1.7
mu_c = 0.4  # Normal distribution for 'c'
sigma_c = 0.1
mu_j = 0.18  # Normal distribution for 'j'
sigma_j = 0.03


np.random.seed(4)

# Function to sample a score based on the individual component
def sample_score(component):
    if component == 'j':
        return np.random.normal(mu_j, sigma_j)
    elif component == 'c':
        return np.random.normal(mu_c, sigma_c)
    elif component == 'b':
        return np.random.beta(alpha_b, beta_param_b)
    else:
        raise ValueError(f"Unknown component: {component}")  #just in case

# Generate unique permutations
def unique_permutations(elements):
    return list(set(itertools.permutations(elements)))

# Generate the unique permutations
bbjj_permutations = unique_permutations(['b', 'b', 'j', 'j'])
ccbb_permutations = unique_permutations(['c', 'c', 'b', 'b'])
jjcc_permutations = unique_permutations(['j', 'j', 'c', 'c'])

#print(bbjj_permutations)

def generate_scores_with_labels(class_label):
    if class_label == 'jjjj':
        scores = [sample_score('j') for _ in range(4)]
        labels = ['j', 'j', 'j', 'j']
    elif class_label == 'bbbb':
        scores = [sample_score('b') for _ in range(4)]
        labels = ['b', 'b', 'b', 'b']
    elif class_label == 'cccc':
        scores = [sample_score('c') for _ in range(4)]
        labels = ['c', 'c', 'c', 'c']
    elif class_label == 'bbjj':
        perm = np.random.choice(len(bbjj_permutations))  # Select a unique permutation
        labels = bbjj_permutations[perm]
        scores = [sample_score(comp) for comp in labels]
    elif class_label == 'ccbb':
        perm = np.random.choice(len(ccbb_permutations))  # Select a unique permutation
        labels = ccbb_permutations[perm]
        scores = [sample_score(comp) for comp in labels]
    elif class_label in ['jjcc', 'ccjj']:  # Both use the same permutations
        perm = np.random.choice(len(jjcc_permutations))  # Select a unique permutation
        labels = jjcc_permutations[perm]
        scores = [sample_score(comp) for comp in labels]
    else:
        raise ValueError(f"Unknown class: {class_label}")  # just in case
    
    return scores, labels

# Generate classes based on the probabilities and sample the scores
N = 1000
classes = ["jjjj", "bbjj", "ccjj", "cccc", "ccbb", "bbbb"]
p = [0.2, 0.2, 0.18, 0.17, 0.15, 0.1]  # probabilities for each class
class_column = np.random.choice(classes, size=N, p=p)

data = []
for c in class_column:
    try:
        scores, labels = generate_scores_with_labels(c)
        data.append(scores + [c] + list(labels))  # Add scores, class, and labels
    except ValueError as e:
        print(e)  # just in case

# Create the DataFrame with the new label columns
df = pd.DataFrame(data, columns=['s1', 's2', 's3', 's4', 'class', 'label_s1', 'label_s2', 'label_s3', 'label_s4'])


df
# Out:
#            s1        s2        s3        s4 class label_s1 label_s2 label_s3  \
# 0    0.674077  0.883516  0.655083  0.799011  bbbb        b        b        b
# 1    0.520235  0.158099  0.491599  0.158290  ccjj        c        j        c
# 2    0.929835  0.867007  0.695784  0.881500  bbbb        b        b        b
# 3    0.312131  0.486232  0.541720  0.492862  cccc        c        c        c
# 4    0.130836  0.370183  0.387333  0.216802  cccc        c        c        c
# ..        ...       ...       ...       ...   ...      ...      ...      ...
# 995  0.552540  0.156200  0.452597  0.193912  ccjj        c        j        c
# 996  0.363478  0.347120  0.194509  0.134027  ccjj        c        c        j
# 997  0.265133  0.860522  0.346954  0.835525  ccbb        c        b        c
# 998  0.725789  0.900351  0.171500  0.157591  bbjj        b        b        j
# 999  0.179134  0.419637  0.210175  0.361795  ccjj        j        c        j
#
#     label_s4
# 0          b
# 1          j
# 2          b
# 3          c
# 4          c
# ..       ...
# 995        j
# 996        j
# 997        b
# 998        j
# 999        c
#
# [1000 rows x 9 columns]

# %%
df['label_s1'].value_counts()
# Out:
# label_s1
# j    391
# c    334
# b    275
# Name: count, dtype: int64

# %%
# Obtener el conteo de cada clase
class_counts = df['class'].value_counts()
print(class_counts)
# Calcular las fracciones dividiendo por el total N
class_fractions = class_counts / N

# Convertir a lista
class_fractions_list = class_fractions.tolist()

class_fractions_list_rounded = [round(fraction, 2) for fraction in class_fractions_list]
print('')
print(class_fractions_list_rounded,'data fraction')
print(p,'true fraction')
# Out:
# class
# jjjj    207
# cccc    182
# ccjj    179
# bbjj    177
# ccbb    149
# bbbb    106
# Name: count, dtype: int64
#
# [0.21, 0.18, 0.18, 0.18, 0.15, 0.11] data fraction
# [0.2, 0.2, 0.18, 0.17, 0.15, 0.1] true fraction

# %%
plt.hist(df['s1'],bins=20,density=False)
plt.show()

# %%
m = 20

# Function to rescale values to the interval [1, m] and convert to integers
def rescale_to_interval(values, m):
    return np.round(values * (m - 1) + 1).astype(int)

# Create a copy of the original DataFrame
df_rescaled = df.copy()

# Apply rescaling to each score column in the new DataFrame
df_rescaled['s1'] = rescale_to_interval(df_rescaled['s1'], m)
df_rescaled['s2'] = rescale_to_interval(df_rescaled['s2'], m)
df_rescaled['s3'] = rescale_to_interval(df_rescaled['s3'], m)
df_rescaled['s4'] = rescale_to_interval(df_rescaled['s4'], m)

# Display the rescaled DataFrame
print(df_rescaled.head())

# Show the value counts for the class column in the rescaled DataFrame
print(df_rescaled['class'].value_counts())

# Check the total number of rows in the rescaled DataFrame
print(len(df_rescaled))
# Out:
#    s1  s2  s3  s4 class label_s1 label_s2 label_s3 label_s4
# 0  14  18  13  16  bbbb        b        b        b        b
# 1  11   4  10   4  ccjj        c        j        c        j
# 2  19  17  14  18  bbbb        b        b        b        b
# 3   7  10  11  10  cccc        c        c        c        c
# 4   3   8   8   5  cccc        c        c        c        c
# class
# jjjj    207
# cccc    182
# ccjj    179
# bbjj    177
# ccbb    149
# bbbb    106
# Name: count, dtype: int64
# 1000

# %%
# Values for the x-axis
x = np.linspace(0, 1, 1000)  # Range of possible values for s1

# Theoretical distributions
pdf_j = norm.pdf(x, mu_j, sigma_j)  # Normal distribution for 'j'
pdf_c = norm.pdf(x, mu_c, sigma_c)  # Normal distribution for 'c'
pdf_b = beta.pdf(x, alpha_b, beta_param_b)  # Beta distribution for 'b'

# Plot the histogram of s1
plt.hist(df['s1'], bins=20, density=True, alpha=0.6, label='Histogram (s1)')

# Plot the theoretical distributions
plt.plot(x, pdf_j*df['label_s1'].value_counts()['j']/N, label='Theoretical j (Normal)', color='blue')
plt.plot(x, pdf_c*df['label_s1'].value_counts()['c']/N, label='Theoretical c (Normal)', color='orange')
plt.plot(x, pdf_b*df['label_s1'].value_counts()['b']/N, label='Theoretical b (Beta)', color='red')

# Add labels and legend
plt.xlabel('Score (s1)')
plt.ylabel('Density')
plt.legend()
plt.title('Comparison of s1 Histogram with Theoretical Distributions')

# Show the plot
plt.show()

# %%
# Valores del eje x reescalados a [1, m]
x_rescaled = np.linspace(1, m, 1000)  # Rango de valores posibles para s1

# Ajustar las distribuciones teóricas a [1, m]
pdf_j_rescaled = norm.pdf((x_rescaled - 1) / (m - 1), mu_j, sigma_j) / (m - 1)  # Normal para 'j' reescalada
pdf_c_rescaled = norm.pdf((x_rescaled - 1) / (m - 1), mu_c, sigma_c) / (m - 1)  # Normal para 'c' reescalada
pdf_b_rescaled = beta.pdf((x_rescaled - 1) / (m - 1), alpha_b, beta_param_b) / (m - 1)  # Beta para 'b' reescalada

# Graficar el histograma de s1 reescalado
plt.hist(df_rescaled['s1'], bins=19, density=True, alpha=0.6, label='Histogram (s1)')

# Graficar las distribuciones teóricas reescaladas
plt.plot(x_rescaled, pdf_j_rescaled * df['label_s1'].value_counts()['j'] / N, label='Theoretical j (Normal)', color='blue')
plt.plot(x_rescaled, pdf_c_rescaled * df['label_s1'].value_counts()['c'] / N, label='Theoretical c (Normal)', color='orange')
plt.plot(x_rescaled, pdf_b_rescaled * df['label_s1'].value_counts()['b'] / N, label='Theoretical b (Beta)', color='red')

# Añadir etiquetas y leyenda
plt.xlabel('Score (s1)')
plt.ylabel('Density')
plt.legend()
plt.title(f'Comparison of s1 Histogram with Theoretical Distributions (Rescaled to [1, {m}])')
plt.xticks(range(1,m+1))
# Mostrar el gráfico
plt.show()

# %%
score = df_rescaled[['s1', 's2', 's3', 's4']].values.tolist()
print(score[:3])
print(len(score))
# Out:
# [[14, 18, 13, 16], [11, 4, 10, 4], [19, 17, 14, 18]]
# 1000

# %%
my_mixture_4d = """
functions {
  real partial_sum(array[,] int score_slice,
                   int start, int end,
                   vector yj,
                   vector yb,
                   vector yc,
                   vector theta)
  {
    real permutation_factor = 1.0/6;
    real partial_target = 0;
    
    vector[6] lp;   // Six distinct classes: jjjj, bbjj (+perm), bbbb, bbcc (+perm), jjcc (+perm), and cccc.
    vector[6] lp2;  // To handle permutations for bbjj
    vector[6] lp3;  // To handle permutations for bbcc
    vector[6] lp4;  // To handle permutations for jjcc.
    
    int slice_length = end - start + 1;

    for (k in 1:slice_length) {
      // Permutations for bbjj
      lp2[1] = log(permutation_factor) + log(yj)[score_slice[k,1]] + log(yj)[score_slice[k,2]] + log(yb)[score_slice[k,3]] + log(yb)[score_slice[k,4]];
      lp2[2] = log(permutation_factor) + log(yj)[score_slice[k,1]] + log(yb)[score_slice[k,2]] + log(yj)[score_slice[k,3]] + log(yb)[score_slice[k,4]];
      lp2[3] = log(permutation_factor) + log(yj)[score_slice[k,1]] + log(yb)[score_slice[k,2]] + log(yb)[score_slice[k,3]] + log(yj)[score_slice[k,4]];
      lp2[4] = log(permutation_factor) + log(yb)[score_slice[k,1]] + log(yj)[score_slice[k,2]] + log(yj)[score_slice[k,3]] + log(yb)[score_slice[k,4]];
      lp2[5] = log(permutation_factor) + log(yb)[score_slice[k,1]] + log(yj)[score_slice[k,2]] + log(yb)[score_slice[k,3]] + log(yj)[score_slice[k,4]];
      lp2[6] = log(permutation_factor) + log(yb)[score_slice[k,1]] + log(yb)[score_slice[k,2]] + log(yj)[score_slice[k,3]] + log(yj)[score_slice[k,4]];

      // Assign probabilities for the six classes
      lp[1] = log(yj)[score_slice[k,1]] + log(yj)[score_slice[k,2]] + log(yj)[score_slice[k,3]] + log(yj)[score_slice[k,4]]; // jjjj
      lp[2] = log_sum_exp(lp2);    // bbjj + permutations
      lp[3] = log(yb)[score_slice[k,1]] + log(yb)[score_slice[k,2]] + log(yb)[score_slice[k,3]] + log(yb)[score_slice[k,4]]; // bbbb

      // Permutations for bbcc
      lp3[1] = log(permutation_factor) + log(yb)[score_slice[k,1]] + log(yb)[score_slice[k,2]] + log(yc)[score_slice[k,3]] + log(yc)[score_slice[k,4]];
      lp3[2] = log(permutation_factor) + log(yb)[score_slice[k,1]] + log(yc)[score_slice[k,2]] + log(yb)[score_slice[k,3]] + log(yc)[score_slice[k,4]];
      lp3[3] = log(permutation_factor) + log(yb)[score_slice[k,1]] + log(yc)[score_slice[k,2]] + log(yc)[score_slice[k,3]] + log(yb)[score_slice[k,4]];
      lp3[4] = log(permutation_factor) + log(yc)[score_slice[k,1]] + log(yb)[score_slice[k,2]] + log(yb)[score_slice[k,3]] + log(yc)[score_slice[k,4]];
      lp3[5] = log(permutation_factor) + log(yc)[score_slice[k,1]] + log(yb)[score_slice[k,2]] + log(yc)[score_slice[k,3]] + log(yb)[score_slice[k,4]];
      lp3[6] = log(permutation_factor) + log(yc)[score_slice[k,1]] + log(yc)[score_slice[k,2]] + log(yb)[score_slice[k,3]] + log(yb)[score_slice[k,4]];
      lp[4] = log_sum_exp(lp3);    // bbcc + permutations

      // Permutations for jjcc
      lp4[1] = log(permutation_factor) + log(yj)[score_slice[k,1]] + log(yj)[score_slice[k,2]] + log(yc)[score_slice[k,3]] + log(yc)[score_slice[k,4]];
      lp4[2] = log(permutation_factor) + log(yj)[score_slice[k,1]] + log(yc)[score_slice[k,2]] + log(yj)[score_slice[k,3]] + log(yc)[score_slice[k,4]];
      lp4[3] = log(permutation_factor) + log(yj)[score_slice[k,1]] + log(yc)[score_slice[k,2]] + log(yc)[score_slice[k,3]] + log(yj)[score_slice[k,4]];
      lp4[4] = log(permutation_factor) + log(yc)[score_slice[k,1]] + log(yj)[score_slice[k,2]] + log(yj)[score_slice[k,3]] + log(yc)[score_slice[k,4]];
      lp4[5] = log(permutation_factor) + log(yc)[score_slice[k,1]] + log(yj)[score_slice[k,2]] + log(yc)[score_slice[k,3]] + log(yj)[score_slice[k,4]];
      lp4[6] = log(permutation_factor) + log(yc)[score_slice[k,1]] + log(yc)[score_slice[k,2]] + log(yj)[score_slice[k,3]] + log(yj)[score_slice[k,4]];
      lp[5] = log_sum_exp(lp4);    // jjcc + permutations

      lp[6] = log(yc)[score_slice[k,1]] + log(yc)[score_slice[k,2]] + log(yc)[score_slice[k,3]] + log(yc)[score_slice[k,4]]; // cccc

      partial_target += log_mix(theta, lp);
    }

    return partial_target;
  }
}

data {
  int<lower=1> m;  // steps in the discretization
  int<lower=1> N;  // data points
  array[N,4] int<lower=1, upper=m> score;  // b-tagging score for jet#1
}

parameters {
  simplex[6] theta;  // Mixture coefficients of 6 classes as a simplex
  
  simplex[m] w_j_mode;  // Dirichlet weights for the background (jjjj and permutations)
  vector<lower=0>[m-1] a_j;  // Normal parameters for background
  
  simplex[m] w_b_mode;  // Dirichlet weights for the signal (bbbb and permutations)
  vector<lower=0>[m-1] a_b;  // Normal parameters for signal
  
  simplex[m] w_c_mode;  // Dirichlet weights for component c (cccc and permutations)
  vector<lower=0>[m-1] a_c;  // Normal parameters for component c
}

transformed parameters {
  ordered[2] y_label_switch_1;
  ordered[2] y_label_switch_2;
  ordered[2] y_label_switch_3;
  ordered[2] y_label_switch_4;
  ordered[2] y_label_switch_5;
  ordered[2] y_label_switch_6;
  ordered[2] y_label_switch_7;

  vector[m] p_j;  // Approximate distribution for j
  vector[m-1] sign_j;  // Signs for combination
  vector[m] logp_j;  // Log-probabilities
  
  sign_j = rep_vector(-1.0, m-1);
  p_j = rep_vector(0.0, m);

  for (k in 1:m) {
    if (k > 1) {
      for (j in 1:(k-1)) {
        sign_j[j] = 1.0;
      }
    }
    logp_j[1] = 0.0;
    for (j in 2:m) {
      logp_j[j] = logp_j[j-1] + sign_j[j-1] * a_j[j-1];
    }
    p_j += softmax(logp_j) * w_j_mode[k];
  }

  vector[m] p_b;  // Approximate distribution for b
  vector[m-1] sign_b;  // Signs for combination
  vector[m] logp_b;  // Log-probabilities

  sign_b = rep_vector(-1.0, m-1);
  p_b = rep_vector(0.0, m);

  for (k in 1:m) {
    if (k > 1) {
      for (j in 1:(k-1)) {
        sign_b[j] = 1.0;
      }
    }
    logp_b[1] = 0.0;
    for (j in 2:m) {
      logp_b[j] = logp_b[j-1] + sign_b[j-1] * a_b[j-1];
    }
    p_b += softmax(logp_b) * w_b_mode[k];
  }
  
  vector[m] p_c;  // Approximate distribution for c
  vector[m-1] sign_c;  // Signs for combination
  vector[m] logp_c;  // Log-probabilities
  
  sign_c = rep_vector(-1.0, m-1);
  p_c = rep_vector(0.0, m);

  for (k in 1:m) {
    if (k > 1) {
      for (j in 1:(k-1)) {
        sign_c[j] = 1.0;
      }
    }
    logp_c[1] = 0.0;
    for (j in 2:m) {
      logp_c[j] = logp_c[j-1] + sign_c[j-1] * a_c[j-1];
    }
    p_c += softmax(logp_c) * w_c_mode[k];
  }

  y_label_switch_1[1] = p_c[5];
  y_label_switch_1[2] = p_j[5];
  
  y_label_switch_2[1] = p_c[4];
  y_label_switch_2[2] = p_j[4];
  
  y_label_switch_3[1] = p_b[5];
  y_label_switch_3[2] = p_j[5];

  y_label_switch_4[1] = p_b[8];
  y_label_switch_4[2] = p_c[8];

  y_label_switch_5[1] = p_j[8];
  y_label_switch_5[2] = p_c[8];
  
  y_label_switch_6[1] = p_c[16];
  y_label_switch_6[2] = p_b[16];

  y_label_switch_7[1] = p_j[16];
  y_label_switch_7[2] = p_b[16];
  



}

model {
  int grainsize = 1;  // Adjust for parallel performance

  // Priors
  theta ~ dirichlet(rep_vector(1.0, 6));

  a_j ~ normal(0, 0.5);
  a_b ~ normal(0, 0.5);
  a_c ~ normal(0, 0.5);

  w_j_mode ~ dirichlet(rep_vector(1.0, m));
  w_b_mode ~ dirichlet(rep_vector(1.0, m));
  w_c_mode ~ dirichlet(rep_vector(1.0, m));

  target += reduce_sum(partial_sum, score, grainsize, p_j, p_b, p_c, theta);
}

"""

# %%
# Start the timer
start_time_4d = time.time()

# Build and sample from the 2D mixture model
model_4d = stan.build(my_mixture_4d, data={'m': m, 'N': len(score), 'score':score},random_seed=33)
fit_4d = model_4d.sample(num_chains=4, num_samples=1000)
df_4d = fit_4d.to_frame()

# Stop the timer
end_time_4d = time.time()

# Calculate the elapsed time
elapsed_time_4d = end_time_4d - start_time_4d

# Print the elapsed time
print(f"Time taken to run the 2D model: {elapsed_time_4d:.2f} seconds")
# Out:
# Building: found in cache, done.
# Messages from stanc:
# Warning in '/tmp/httpstan_m4tz572u/model_ijn43xfq.stan', line 189, column 12: The
#     variable partial_sum may not have been assigned a value before its use.
# Sampling:   0%
# Sampling:   0% (1/8000)
# Sampling:   0% (2/8000)
# Sampling:   0% (3/8000)
# Sampling:   0% (4/8000)
# Sampling:   1% (103/8000)
# Sampling:   3% (203/8000)
# Sampling:   4% (303/8000)
# Sampling:   5% (403/8000)
# Sampling:   6% (503/8000)
# Sampling:   8% (603/8000)
# Sampling:   9% (702/8000)
# Sampling:  10% (802/8000)
# Sampling:  11% (902/8000)
# Sampling:  13% (1001/8000)
# Sampling:  14% (1101/8000)
# Sampling:  15% (1200/8000)
# Sampling:  16% (1300/8000)
# Sampling:  18% (1400/8000)
# Sampling:  18% (1401/8000)
# Sampling:  19% (1500/8000)
# Sampling:  20% (1600/8000)
# Sampling:  21% (1700/8000)
# Sampling:  22% (1800/8000)
# Sampling:  24% (1900/8000)
# Sampling:  25% (2000/8000)
# Sampling:  26% (2100/8000)
# Sampling:  28% (2200/8000)
# Sampling:  29% (2300/8000)
# Sampling:  30% (2400/8000)
# Sampling:  31% (2500/8000)
# Sampling:  32% (2600/8000)
# Sampling:  34% (2700/8000)
# Sampling:  35% (2800/8000)
# Sampling:  36% (2900/8000)
# Sampling:  38% (3000/8000)
# Sampling:  39% (3100/8000)
# Sampling:  40% (3200/8000)
# Sampling:  41% (3300/8000)
# Sampling:  42% (3400/8000)
# Sampling:  44% (3500/8000)
# Sampling:  45% (3600/8000)
# Sampling:  46% (3700/8000)
# Sampling:  48% (3800/8000)
# Sampling:  49% (3900/8000)
# Sampling:  50% (4000/8000)
# Sampling:  51% (4100/8000)
# Sampling:  52% (4200/8000)
# Sampling:  54% (4300/8000)
# Sampling:  55% (4400/8000)
# Sampling:  56% (4500/8000)
# Sampling:  58% (4600/8000)
# Sampling:  59% (4701/8000)
# Sampling:  60% (4801/8000)
# Sampling:  61% (4902/8000)
# Sampling:  63% (5001/8000)
# Sampling:  64% (5100/8000)
# Sampling:  65% (5200/8000)
# Sampling:  66% (5301/8000)
# Sampling:  68% (5401/8000)
# Sampling:  69% (5501/8000)
# Sampling:  70% (5600/8000)
# Sampling:  71% (5700/8000)
# Sampling:  72% (5800/8000)
# Sampling:  74% (5900/8000)
# Sampling:  75% (6000/8000)
# Sampling:  76% (6100/8000)
# Sampling:  78% (6200/8000)
# Sampling:  79% (6300/8000)
# Sampling:  80% (6400/8000)
# Sampling:  81% (6500/8000)
# Sampling:  82% (6600/8000)
# Sampling:  84% (6700/8000)
# Sampling:  85% (6800/8000)
# Sampling:  86% (6900/8000)
# Sampling:  88% (7000/8000)
# Sampling:  89% (7100/8000)
# Sampling:  90% (7200/8000)
# Sampling:  91% (7300/8000)
# Sampling:  92% (7400/8000)
# Sampling:  94% (7500/8000)
# Sampling:  95% (7600/8000)
# Sampling:  96% (7700/8000)
# Sampling:  98% (7800/8000)
# Sampling:  99% (7900/8000)
# Sampling: 100% (8000/8000)
# Sampling: 100% (8000/8000), done.
# Messages received during sampling:
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.0462504, but should be greater than the previous element, 0.116132 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0147247, but should be greater than the previous element, 0.0628164 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0150288, but should be greater than the previous element, 0.043314 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.0289854, but should be greater than the previous element, 0.0558723 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_6 is not a valid ordered vector. The element at 2 is 0.00922531, but should be greater than the previous element, 0.0123547 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 86, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0435496, but should be greater than the previous element, 0.15557 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0339042, but should be greater than the previous element, 0.0732085 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0425998, but should be greater than the previous element, 0.100915 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0156096, but should be greater than the previous element, 0.0401068 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0189462, but should be greater than the previous element, 0.0628612 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0264415, but should be greater than the previous element, 0.0267986 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0506461, but should be greater than the previous element, 0.0702293 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_2 is not a valid ordered vector. The element at 2 is 0.0402215, but should be greater than the previous element, 0.111911 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 82, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_5 is not a valid ordered vector. The element at 2 is 0.0420796, but should be greater than the previous element, 0.0656332 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 85, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.0551113, but should be greater than the previous element, 0.0688749 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0673649, but should be greater than the previous element, 0.138558 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.052615, but should be greater than the previous element, 0.0960121 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.021047, but should be greater than the previous element, 0.0364325 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_2 is not a valid ordered vector. The element at 2 is 0.0255712, but should be greater than the previous element, 0.111082 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 82, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_5 is not a valid ordered vector. The element at 2 is 0.0859399, but should be greater than the previous element, 0.121158 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 85, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0339775, but should be greater than the previous element, 0.0756055 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_3 is not a valid ordered vector. The element at 2 is 0.038271, but should be greater than the previous element, 0.0644394 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 83, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0260269, but should be greater than the previous element, 0.0799312 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_2 is not a valid ordered vector. The element at 2 is 0.116144, but should be greater than the previous element, 0.1502 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 82, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0293925, but should be greater than the previous element, 0.0665261 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0186618, but should be greater than the previous element, 0.0589675 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0378503, but should be greater than the previous element, 0.0959076 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0450489, but should be greater than the previous element, 0.102332 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.050127, but should be greater than the previous element, 0.0687796 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.01236, but should be greater than the previous element, 0.0324331 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_3 is not a valid ordered vector. The element at 2 is 0.0821475, but should be greater than the previous element, 0.0963217 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 83, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0299035, but should be greater than the previous element, 0.0818213 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0352605, but should be greater than the previous element, 0.0515357 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_2 is not a valid ordered vector. The element at 2 is 0.0194884, but should be greater than the previous element, 0.0262209 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 82, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.031243, but should be greater than the previous element, 0.0895882 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.0710796, but should be greater than the previous element, 0.0824488 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0881202, but should be greater than the previous element, 0.0999172 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_2 is not a valid ordered vector. The element at 2 is 0.0714873, but should be greater than the previous element, 0.0921799 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 82, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.0329807, but should be greater than the previous element, 0.0465978 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.043947, but should be greater than the previous element, 0.0821319 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
#   Gradient evaluation took 0.001664 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 16.64 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_6 is not a valid ordered vector. The element at 2 is 0.00831202, but should be greater than the previous element, 0.0379931 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 86, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_6 is not a valid ordered vector. The element at 2 is 2.71517e-06, but should be greater than the previous element, 0.0319033 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 86, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0766577, but should be greater than the previous element, 0.109739 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is -nan, but should be greater than the previous element, 0.247089 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_7 is not a valid ordered vector. The element at 2 is 0.00028854, but should be greater than the previous element, 0.00133049 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 87, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_2 is not a valid ordered vector. The element at 2 is 0.062197, but should be greater than the previous element, 0.116937 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 82, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.039628, but should be greater than the previous element, 0.0533317 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_2 is not a valid ordered vector. The element at 2 is 0.0172487, but should be greater than the previous element, 0.0970092 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 82, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0220025, but should be greater than the previous element, 0.0228627 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_2 is not a valid ordered vector. The element at 2 is 0.0191468, but should be greater than the previous element, 0.0447757 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 82, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0680263, but should be greater than the previous element, 0.0777735 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0544089, but should be greater than the previous element, 0.0594422 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0195053, but should be greater than the previous element, 0.132385 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0302152, but should be greater than the previous element, 0.0776833 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_6 is not a valid ordered vector. The element at 2 is 0.0744279, but should be greater than the previous element, 0.0751619 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 86, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.00987431, but should be greater than the previous element, 0.0103339 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.100106, but should be greater than the previous element, 0.218832 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0241319, but should be greater than the previous element, 0.112867 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0905886, but should be greater than the previous element, 0.121874 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0311225, but should be greater than the previous element, 0.0813956 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0694027, but should be greater than the previous element, 0.0971402 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0318653, but should be greater than the previous element, 0.09092 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0443279, but should be greater than the previous element, 0.106834 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.0502232, but should be greater than the previous element, 0.0761526 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.0764669, but should be greater than the previous element, 0.116532 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_3 is not a valid ordered vector. The element at 2 is 0.027717, but should be greater than the previous element, 0.105731 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 83, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_3 is not a valid ordered vector. The element at 2 is 0.0492194, but should be greater than the previous element, 0.0954228 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 83, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0701272, but should be greater than the previous element, 0.109102 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.0136549, but should be greater than the previous element, 0.0928994 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.00859939, but should be greater than the previous element, 0.174787 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_5 is not a valid ordered vector. The element at 2 is 0.0330908, but should be greater than the previous element, 0.0532304 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 85, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0106659, but should be greater than the previous element, 0.0241302 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0463713, but should be greater than the previous element, 0.0946185 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_3 is not a valid ordered vector. The element at 2 is 0.0816843, but should be greater than the previous element, 0.0886032 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 83, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0237697, but should be greater than the previous element, 0.0852995 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0321574, but should be greater than the previous element, 0.107838 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0114716, but should be greater than the previous element, 0.125844 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0561699, but should be greater than the previous element, 0.122063 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_6 is not a valid ordered vector. The element at 2 is 0.0188369, but should be greater than the previous element, 0.0202598 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 86, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0393761, but should be greater than the previous element, 0.0587602 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0297467, but should be greater than the previous element, 0.0325373 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0766843, but should be greater than the previous element, 0.0904404 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
#   Gradient evaluation took 0.003716 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 37.16 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.0775856, but should be greater than the previous element, 0.0920996 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.0825113, but should be greater than the previous element, 0.0859137 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_6 is not a valid ordered vector. The element at 2 is 0.00803394, but should be greater than the previous element, 0.0277219 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 86, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.0763284, but should be greater than the previous element, 0.110024 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.054264, but should be greater than the previous element, 0.0571043 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.0520566, but should be greater than the previous element, 0.0554332 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is -nan, but should be greater than the previous element, 0.111111 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_6 is not a valid ordered vector. The element at 2 is 0.00144678, but should be greater than the previous element, 0.0111659 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 86, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.0562585, but should be greater than the previous element, 0.0587217 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.0466991, but should be greater than the previous element, 0.0468842 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.0479093, but should be greater than the previous element, 0.0479796 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.046686, but should be greater than the previous element, 0.0467307 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.0466137, but should be greater than the previous element, 0.0466918 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.0459758, but should be greater than the previous element, 0.0462296 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.0475293, but should be greater than the previous element, 0.0479559 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.0467272, but should be greater than the previous element, 0.047336 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.050035, but should be greater than the previous element, 0.05036 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.0484182, but should be greater than the previous element, 0.0493334 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.0508578, but should be greater than the previous element, 0.0513975 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.05054, but should be greater than the previous element, 0.050842 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.0554374, but should be greater than the previous element, 0.0554638 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.0528886, but should be greater than the previous element, 0.0530022 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
# ...
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_2 is not a valid ordered vector. The element at 2 is 0.0838754, but should be greater than the previous element, 0.116211 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 82, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0182992, but should be greater than the previous element, 0.0660825 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.012116, but should be greater than the previous element, 0.0656943 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_3 is not a valid ordered vector. The element at 2 is 0.0356598, but should be greater than the previous element, 0.096538 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 83, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_3 is not a valid ordered vector. The element at 2 is 0.0740299, but should be greater than the previous element, 0.0808166 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 83, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_6 is not a valid ordered vector. The element at 2 is 0.0143187, but should be greater than the previous element, 0.032456 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 86, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_3 is not a valid ordered vector. The element at 2 is 0.0386021, but should be greater than the previous element, 0.065289 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 83, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_2 is not a valid ordered vector. The element at 2 is 0.0459114, but should be greater than the previous element, 0.120073 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 82, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.027233, but should be greater than the previous element, 0.1158 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_2 is not a valid ordered vector. The element at 2 is 0.0499236, but should be greater than the previous element, 0.0590412 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 82, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0449269, but should be greater than the previous element, 0.0755014 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.0907212, but should be greater than the previous element, 0.108421 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.0270786, but should be greater than the previous element, 0.0715894 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0398832, but should be greater than the previous element, 0.108382 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0245958, but should be greater than the previous element, 0.052539 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.0309615, but should be greater than the previous element, 0.0612338 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_3 is not a valid ordered vector. The element at 2 is 0.0980394, but should be greater than the previous element, 0.124178 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 83, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0153293, but should be greater than the previous element, 0.0635662 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.0500316, but should be greater than the previous element, 0.106555 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.0688395, but should be greater than the previous element, 0.0822246 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.1254, but should be greater than the previous element, 0.146202 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_2 is not a valid ordered vector. The element at 2 is 0.0648881, but should be greater than the previous element, 0.0930538 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 82, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_3 is not a valid ordered vector. The element at 2 is 0.0863106, but should be greater than the previous element, 0.113439 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 83, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0142386, but should be greater than the previous element, 0.0427442 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_2 is not a valid ordered vector. The element at 2 is 0.0235933, but should be greater than the previous element, 0.0749279 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 82, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_2 is not a valid ordered vector. The element at 2 is 0.055019, but should be greater than the previous element, 0.100052 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 82, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_5 is not a valid ordered vector. The element at 2 is 0.0478837, but should be greater than the previous element, 0.0495833 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 85, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_3 is not a valid ordered vector. The element at 2 is 0.120053, but should be greater than the previous element, 0.161726 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 83, column 2 to column 30)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_6 is not a valid ordered vector. The element at 2 is 0.0116474, but should be greater than the previous element, 0.0340483 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 86, column 2 to column 30)
#   Gradient evaluation took 0.006945 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 69.45 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_6 is not a valid ordered vector. The element at 2 is 1.84666e-309, but should be greater than the previous element, 0.00198722 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 86, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_6 is not a valid ordered vector. The element at 2 is 1.86508e-309, but should be greater than the previous element, 0.000216534 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 86, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_6 is not a valid ordered vector. The element at 2 is 1.78076e-08, but should be greater than the previous element, 0.0145839 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 86, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_6 is not a valid ordered vector. The element at 2 is 0.00528808, but should be greater than the previous element, 0.0145857 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 86, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is -nan, but should be greater than the previous element, 3.70369e-310 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_3 is not a valid ordered vector. The element at 2 is 0.0555556, but should be greater than the previous element, 0.0588235 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 83, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_1 is not a valid ordered vector. The element at 2 is 0.0137361, but should be greater than the previous element, 0.0694976 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 81, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_ijn43xfq_namespace::log_prob: y_label_switch_4 is not a valid ordered vector. The element at 2 is 0.0674577, but should be greater than the previous element, 0.0884853 (in '/tmp/httpstan_ln7d66d6/model_ijn43xfq.stan', line 84, column 2 to column 30)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
# Time taken to run the 2D model: 135.97 seconds

# %%
df_ordenado = df_4d.sort_values(by='lp__', ascending=False)  #ordeno por probabilidad
df_ordenado[:5]
# Out:
# parameters         lp__  accept_stat__  stepsize__  treedepth__  n_leapfrog__  \
# draws
# 3208       -9922.233990       0.981516    0.129922          5.0          31.0
# 540        -9923.310760       0.957524    0.129922          5.0          31.0
# 3535       -9924.573487       0.891802    0.117540          5.0          31.0
# 2799       -9924.671188       0.906066    0.117540          5.0          31.0
# 3216       -9924.950540       0.973075    0.129922          5.0          31.0
#
# parameters  divergent__     energy__   theta.1   theta.2   theta.3  ...  \
# draws                                                               ...
# 3208                0.0  9979.514142  0.206884  0.178487  0.105828  ...
# 540                 0.0  9991.393688  0.216922  0.176947  0.104916  ...
# 3535                0.0  9977.327666  0.206134  0.202040  0.098651  ...
# 2799                0.0  9989.314666  0.211964  0.173117  0.078457  ...
# 3216                0.0  9982.838687  0.232063  0.185593  0.104283  ...
#
# parameters  logp_c.11  logp_c.12  logp_c.13  logp_c.14  logp_c.15  logp_c.16  \
# draws
# 3208         6.790393   7.978829   8.876192   9.598580   9.819017  10.649059
# 540          7.161701   8.352056   9.553940  10.493131  10.958061  11.648969
# 3535         8.296644   9.228013  10.203124  11.308732  11.691697  12.552305
# 2799         8.343988   9.100149  10.413545  11.624493  12.309497  13.068215
# 3216         7.849693   8.925508   9.911832  10.707556  11.049059  11.884103
#
# parameters  logp_c.17  logp_c.18  logp_c.19  logp_c.20
# draws
# 3208        11.162701  11.555223  11.791816  12.268361
# 540         11.813935  12.904390  13.207093  13.516323
# 3535        12.902480  13.159506  13.312949  13.800804
# 2799        13.076152  13.315898  13.811293  14.726908
# 3216        12.533331  12.846855  13.771320  14.216657
#
# [5 rows x 321 columns]

# %%
#Normalizing and plotting inferred distributions
for i in range(500):
    # Extract the p_j and p_b values for the current sample
    p_j_values = np.array([df_ordenado.iloc[i]['p_j.' + str(x)] for x in range(1, 21)])
    p_b_values = np.array([df_ordenado.iloc[i]['p_b.' + str(x)] for x in range(1, 21)])
    p_c_values = np.array([df_ordenado.iloc[i]['p_c.' + str(x)] for x in range(1, 21)])
    
    # Plot the normalized curves
    if i == 0:
        plt.plot(range(1, 21), p_j_values, lw = 1,color='red', label='p_j')
        plt.plot(range(1, 21), p_b_values, lw = 1,color='blue', label='p_b')
        plt.plot(range(1, 21), p_c_values, lw = 1,color='green', label='p_c')

    else:
        plt.plot(range(1, 21), p_j_values, lw = 0.2,color='red')
        plt.plot(range(1, 21), p_b_values, lw = 0.2,color='blue')
        plt.plot(range(1, 21), p_c_values, lw = 0.2,color='green')


# Graficar las distribuciones teóricas reescaladas
plt.plot(x_rescaled, pdf_j_rescaled * df['label_s1'].value_counts()['j'] / N, label='Theoretical j (Normal)', ls='--', lw=2, color='darkred')
plt.plot(x_rescaled, pdf_c_rescaled * df['label_s1'].value_counts()['c'] / N, label='Theoretical c (Normal)', ls='--', lw=2, color='darkgreen')
plt.plot(x_rescaled, pdf_b_rescaled * df['label_s1'].value_counts()['b'] / N, label='Theoretical b (Beta)', ls='--', lw=2, color='darkblue')

plt.hist(df_rescaled['s1'], bins=19, density=True, alpha=0.6, label='Histogram (s1)')

plt.xticks(np.arange(1,m+1))
plt.xlim(1,m)
plt.legend()
#plt.grid(alpha=0.5)
plt.show()

# %%
(pdf_j_rescaled * df['label_s1'].value_counts()['j'] / N).sum()
# Out:
# 20.55836840278443

# %%
df_4d
# Out:
# parameters          lp__  accept_stat__  stepsize__  treedepth__  \
# draws
# 0           -9927.448015       0.970499    0.129922          5.0
# 1           -9946.854148       0.772916    0.117483          5.0
# 2          -10797.915065       0.952300    0.010803          4.0
# 3           -9947.602543       0.959752    0.117540          5.0
# 4           -9942.006288       0.982119    0.129922          5.0
# ...                  ...            ...         ...          ...
# 3995        -9931.661914       0.896786    0.117540          5.0
# 3996        -9944.640877       0.938692    0.129922          5.0
# 3997        -9952.266229       0.994457    0.117483          5.0
# 3998       -10717.792340       0.916662    0.010803          3.0
# 3999        -9946.087134       0.835023    0.117540          5.0
#
# parameters  n_leapfrog__  divergent__      energy__   theta.1   theta.2  \
# draws
# 0                   31.0          0.0   9989.415061  0.211469  0.176080
# 1                   31.0          0.0  10004.424781  0.218976  0.184967
# 2                   21.0          1.0  10856.299086  0.253268  0.170520
# 3                   31.0          0.0  10016.098715  0.226370  0.181359
# 4                   31.0          0.0   9992.413425  0.229497  0.168540
# ...                  ...          ...           ...       ...       ...
# 3995                31.0          0.0   9996.793218  0.209687  0.185155
# 3996                31.0          0.0  10004.402654  0.209882  0.201319
# 3997                31.0          0.0  10009.806092  0.226968  0.167468
# 3998                12.0          1.0  10771.800175  0.450372  0.117857
# 3999                31.0          0.0  10000.858829  0.223497  0.145905
#
# parameters   theta.3  ...  logp_c.11  logp_c.12  logp_c.13  logp_c.14  \
# draws                 ...
# 0           0.122822  ...   9.053731   9.658582  10.936210  12.216225
# 1           0.088575  ...   7.565064   8.983894   9.851677  10.450217
# 2           0.371904  ...   5.126640   5.473970   6.877575   8.512182
# 3           0.108371  ...   7.134880   8.458575   9.859976  10.519493
# 4           0.084264  ...   7.770034   8.991825  10.112961  11.459877
# ...              ...  ...        ...        ...        ...        ...
# 3995        0.115644  ...   8.633849   9.677697  10.816270  12.498107
# 3996        0.095106  ...   7.407196   8.565286   9.487937  10.276250
# 3997        0.100884  ...  10.633317  11.726387  12.578864  13.295573
# 3998        0.345283  ...   5.728289   6.062687   7.578515   9.187431
# 3999        0.095149  ...   6.961115   7.980900   9.000169   9.895150
#
# parameters  logp_c.15  logp_c.16  logp_c.17  logp_c.18  logp_c.19  logp_c.20
# draws
# 0           13.113241  13.288381  13.443048  13.648301  13.955764  15.157406
# 1           10.659314  11.059903  12.044707  12.412827  12.848876  13.360142
# 2            8.956464  10.677850  11.901693  13.391821  13.520748  15.322100
# 3           11.356794  11.629558  12.035267  12.400086  13.019547  13.338551
# 4           11.613409  11.622197  11.913767  12.338243  13.491442  13.543535
# ...               ...        ...        ...        ...        ...        ...
# 3995        12.852644  13.048043  14.082186  14.357456  14.606256  14.910815
# 3996        10.547703  11.406217  12.520122  13.044513  13.689082  14.592293
# 3997        14.452270  15.595770  16.448063  16.714045  16.987063  17.616811
# 3998         9.608758  10.998342  12.156323  13.416071  13.563854  15.569724
# 3999         9.915014  10.377264  10.524133  11.396394  11.941770  12.676392
#
# [4000 rows x 321 columns]

# %%
# Now define the posterior_4d with the relevant diagnostics columns
posterior_4d = df_4d[['accept_stat__', 'stepsize__', 'treedepth__', 'n_leapfrog__', 'divergent__', 'energy__']]

# Create subplots for each of the 6 diagnostic parameters
fig, axes = plt.subplots(2, 3, figsize=(12, 8), dpi=200)

# List of the diagnostic parameters
parameters = ['accept_stat__', 'stepsize__', 'treedepth__', 'n_leapfrog__', 'divergent__', 'energy__']

# Loop over the parameters and create histograms in subplots
for i, param in enumerate(parameters):
    row = i // 3  # Define the row for the subplot
    col = i % 3   # Define the column for the subplot
    axes[row, col].hist(posterior_4d[param], bins=30, histtype='step', density=True)
    axes[row, col].set_title(param, fontsize=10)

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plots
plt.show()

# %%
posterior = az.from_pystan(fit_4d)

# Get the ArviZ summary
summary_df = az.summary(posterior)

summary_df
# Out:
# /home/tomas/.local/lib/python3.8/site-packages/arviz/stats/diagnostics.py:592: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/tomas/.local/lib/python3.8/site-packages/arviz/stats/diagnostics.py:592: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/tomas/.local/lib/python3.8/site-packages/arviz/stats/diagnostics.py:592: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
#               mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# theta[0]     0.271  0.091   0.195    0.455      0.044    0.034       7.0
# theta[1]     0.162  0.025   0.113    0.194      0.011    0.008       7.0
# theta[2]     0.160  0.104   0.081    0.348      0.051    0.039       7.0
# theta[3]     0.107  0.052   0.012    0.154      0.025    0.019       7.0
# theta[4]     0.159  0.047   0.062    0.205      0.023    0.017       7.0
# ...            ...    ...     ...      ...        ...      ...       ...
# logp_c[15]  11.553  1.014  10.091   13.304      0.326    0.237       9.0
# logp_c[16]  12.243  0.882  10.826   14.048      0.161    0.115      31.0
# logp_c[17]  12.882  0.853  11.192   14.575      0.020    0.014     847.0
# logp_c[18]  13.226  0.897  11.545   15.021      0.033    0.026     613.0
# logp_c[19]  14.030  1.072  11.949   15.578      0.276    0.199      16.0
#
#             ess_tail  r_hat
# theta[0]        16.0   1.57
# theta[1]        15.0   1.52
# theta[2]        27.0   1.53
# theta[3]        11.0   1.59
# theta[4]        12.0   1.59
# ...              ...    ...
# logp_c[15]      59.0   1.34
# logp_c[16]    2838.0   1.08
# logp_c[17]    2699.0   1.16
# logp_c[18]    2559.0   1.15
# logp_c[19]     571.0   1.16
#
# [314 rows x 9 columns]

# %%
summary_df['r_hat'].values
# Out:
# array([1.57, 1.52, 1.53, 1.59, 1.59, 1.59, 1.05, 1.05, 1.56, 1.54, 1.36,
#        1.38, 1.53, 1.55, 1.53, 1.54, 1.57, 1.54, 1.54, 1.53, 1.58, 1.57,
#        1.53, 1.53, 1.58, 1.57, 1.24, 1.13, 1.53, 1.56, 1.59, 1.16, 1.18,
#        1.34, 1.35, 1.51, 1.34, 1.52, 1.1 , 1.3 , 1.4 , 1.34, 1.08, 1.1 ,
#        1.53, 1.25, 1.47, 1.56, 1.55, 1.6 , 1.24, 1.14, 1.07, 1.42, 1.23,
#        1.51, 1.41, 1.22, 1.43, 1.28, 1.16, 1.33, 1.39, 1.33, 1.48, 1.44,
#        1.09, 1.55, 1.44, 1.54, 1.38, 1.17, 1.22, 1.23, 1.52, 1.53, 1.38,
#        1.53, 1.09, 1.56, 1.07, 1.36, 1.45, 1.53, 1.58, 1.55, 1.57, 1.53,
#        1.55, 1.59, 1.13, 1.24, 1.56, 1.18, 1.15, 1.42, 1.43, 1.59, 1.53,
#        1.17, 1.59, 1.36, 1.27, 1.58, 1.25, 1.17, 1.28, 1.55, 1.55, 1.53,
#        1.31, 1.41, 1.11, 1.33, 1.57, 1.07, 1.29, 1.42, 1.5 , 1.38, 1.42,
#        1.09, 1.57, 1.42, 1.58, 1.55, 1.56, 1.58, 1.58, 1.48, 1.53, 1.55,
#        1.53, 1.59, 1.57, 1.57, 1.57, 1.07, 1.04, 1.53, 1.56, 1.58, 1.56,
#        1.54, 1.55, 1.56, 1.54, 1.53, 1.55, 1.53, 1.53, 1.57, 1.57, 1.55,
#        1.54, 1.56, 1.54,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan, 1.24, 1.2 , 1.52, 1.03, 1.52, 1.53, 1.52, 1.53, 1.53, 1.2 ,
#        1.24, 1.04, 1.06, 1.04, 1.05, 1.06, 1.08, 1.07, 1.09, 1.58, 1.58,
#        1.53, 1.53, 1.58, 1.54, 1.54, 1.48, 1.13, 1.21, 1.56, 1.59, 1.54,
#        1.59, 1.59, 1.57, 1.57, 1.57, 1.58, 1.44,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan, 1.44, 1.13, 1.56, 1.54, 1.53, 1.53,
#        1.53, 1.53, 1.54, 1.53, 1.54, 1.54, 1.55, 1.55, 1.54, 1.54, 1.54,
#        1.54, 1.54, 1.59, 1.55, 1.54, 1.55, 1.42, 1.55, 1.52, 1.53, 1.53,
#        1.53, 1.54, 1.42, 1.39, 1.59, 1.57, 1.59, 1.58, 1.58, 1.58, 1.59,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan, 1.25, 1.09,
#        1.36, 1.55, 1.52, 1.57, 1.58, 1.59, 1.57, 1.58, 1.58, 1.56, 1.57,
#        1.57, 1.34, 1.08, 1.16, 1.15, 1.16])
